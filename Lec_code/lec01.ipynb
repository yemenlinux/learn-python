# %% [markdown]
# ## كتابة المتغيرات

# %%
x = 5
print(x)
print(f'Type of x is {type(x)}')

# %%
x = 5.05
print(x)
print(f'Type of x is {type(x)}')

# %%
x = "5"
print(x)
print(f'Type of x is {type(x)}')

# %% [markdown]
# ## تعيين قيمة لمتغير وإجراء عملية حسابية
#
# المثال التالي لحساب مساحة دائرة من نصف القطر

# %%
pi = 3.14159
radius = 2.2
# area of circle equation <- this is a comment
area = pi*(radius**2)
print(area)

# %% [markdown]
# <p style="text-align: left; direction: rtl; font-size: 2em;">
# تكتب الملاحظة بعد رمز المربع #
#
# </p>

# %%
# change values of radius <- another comment
# use comments to help others understand what you are doing in code
radius = radius + 1
print(area)     # area doesn't change
area = pi*(radius**2)
print(area)

# %% [markdown]
# ماذا تلاحظ في النتيجة السابقة؟
#
# لم تتغير قيمة المساحة إلا بعد إجراء الحساب مرة أخرى

# %% [markdown]
# ## جرب تظليل الكود ثم استخدم
# CTRL+/

# %%
#############################
#### COMMENTING LINES #######
#############################
# to comment MANY lines at a time, highlight all of them then CTRL+1
# do CTRL+/ again to uncomment them
# try it on the next few lines below!

area = pi*(radius**2)
print(area)
radius = radius + 1
area = pi*(radius**2)
print(area)

# %% [markdown]
# ## الاكمال التلقائي
#
# <p style="text-align: left; direction: rtl; font-size: 1em;">
# يمكن كتابة اسم متغير طويل ثم عند اعادة استخدامه
# اطبع أول ثلاثة أحرف (مثلاً) ثم اضغط زر Tab لاكمال كتابة المتغير تلقائياً
# </p>

# %%
#############################
#### AUTOCOMPLETE #######
#############################
# Spyder can autocomplete names for you
# start typing a variable name defined in your program and hit tab 
# before you finish typing -- try it below

# define a variable
a_very_long_variable_name_dont_name_them_this_long_pls = 0

# below, start typing a_ve then hit tab... cool, right!
# use autocomplete to change the value of that variable to 1

# use autocomplete to write a line that prints the value of that long variable
# notice that Spyder also automatically adds the closed parentheses for you!

# %%
a_very_long_variable_name_dont_name_them_this_long_pls

# %%
d = {'a': 1, 'b':2}
print(d)

# %%
print(d['a'])

# %%
d['a'] =5

# %%
print(d['a'])

# %%
d.keys()

# %%
d.values()

# %%
list?

# %%
help(list)
