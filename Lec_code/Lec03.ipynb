# %% [markdown]
# ## EXAMPLE: for loops over strings

# %% [markdown]
# ## الفهرسة

# %%
s = "abc"

# %%
len(s)

# %%
s[0]

# %%
s[1]

# %%
s[2]

# %%
s[-1]

# %%
s[-2]

# %%
s[-3]

# %% [markdown]
# ## الشرائح

# %%
s = "abcdefgh"

# %%
s[3:6]

# %%
s[3:6:2]

# %%
s[::]

# %%
s[::-1]

# %%
s[4:1:-2]

# %%
s[4:0:-1]

# %%
s[::-3]

# %%
list(range(25,10, 2))

# %% [markdown]
# ## غير قابلة للتبديل

# %%
s = "hello"

# %%
s[0] = 'y'

# %%
s[1:len(s)]

# %%
s = 'y'+s[1:len(s)] 
s

# %% [markdown]
# ## استخدام الفهرسة في البحث
# <p style="text-align: center; direction: rtl; font-size: 2em;">
#     ابحث حن حرفي u أو i في مصفوفة
# </p>

# %%
s = "demo loopsu"

# %%
range(len(s))

# %%
for index in range(len(s)):
    print(f"debug msg  index = {index}")
    if s[index] == 'i' or s[index] == 'u':
        print("There is an i or u")

# %%
for char in s:
    print(f"debug msg index = {char}")
    if char == 'i' or char == 'u':
        print("There is an i or u")

# %%
## EXAMPLE: while loops and strings
## CHALLENGE: rewrite while loop with a for loop
####################
an_letters = "aefhilmnorsxAEFHILMNORSX"
word = input("I will cheer for you! Enter a word: ")
times = int(input("Enthusiasm level (1-10): "))

i = 0
while i < len(word):
   char = word[i]
   if char in an_letters:
       print("Give me an " + char + "! " + char)
   else:
       print("Give me a  " + char + "! " + char)
   i += 1

print("What does that spell?")

for i in range(times):
   print(word, "!!!")

# %%
s1 = "mit u rock"
s2 = "i rule mit"
if len(s1) == len(s2):
    for char1 in s1:
        for char2 in s2:
            if char1 == char2:
                print("common letter")
                break

# %% [markdown]
# ## التخمين والفحص

# %% [markdown]
# ## إيجاد الجذر التكعيبي

# %%
## EXAMPLE: perfect cube 
####################
cube = 27
cube = 554399338375
for guess in range(cube+1):
   if guess**3 == cube:
       print("Cube root of", cube, "is", guess)
       # loops keeps going even after found the cube root
# Out:
# Cube root of 554399338375 is 8215
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 cube = 554399338375
#       5 for guess in range(cube+1):
# ----> 6    if guess**3 == cube:
#       7        print("Cube root of", cube, "is", guess)
#       8        # loops keeps going even after found the cube root
#
# KeyboardInterrupt:

# %%
## EXAMPLE: guess and check cube root 
####################
cube = 27
# cube = 554399338375
for guess in range(abs(cube)+1):
   # passed all potential cube roots
   if guess**3 >= abs(cube):
       # no need to keep searching
       break
if guess**3 != abs(cube):
   print(cube, 'is not a perfect cube')
else:
   if cube < 0:
       guess = -guess
   print('Cube root of ' + str(cube) + ' is ' + str(guess))
# Out:
# Cube root of 27 is 3

# %% [markdown]
# ## الحل التقريبي

# %%
## EXAMPLE: approximate cube root 
####################
cube = 27
# cube = 554399338375
#cube = 10000
epsilon = 0.1
guess = 0.0
increment = 0.01
num_guesses = 0
# look for close enough answer and make sure
# didn't accidentally skip the close enough bound
while abs(guess**3 - cube) >= epsilon and guess <= cube:
   guess += increment
   num_guesses += 1
print('num_guesses =', num_guesses)
if abs(guess**3 - cube) >= epsilon:
   print('Failed on cube root of', cube, "with these parameters.")
else:
   print(guess, 'is close to the cube root of', cube)
# Out:
# num_guesses = 300
# 2.99999999999998 is close to the cube root of 27

# %% [markdown]
# ## البحث ذو القسمين

# %%
## EXAMPLE: bisection cube root (only positive cubes!)
####################
cube = 27
# cube = 8120601
# won't work with x < 1 because initial upper bound is less than ans
#cube = 0.25
epsilon = 0.01
num_guesses = 0
low = 0
high = cube
guess = (high + low)/2.0
while abs(guess**3 - cube) >= epsilon:
   if guess**3 < cube:
       # look only in upper half search space
       low = guess
   else:
       # look only in lower half search space
       high = guess
   # next guess is halfway in search space
   guess = (high + low)/2.0
   num_guesses += 1
print('num_guesses =', num_guesses)
print(guess, 'is close to the cube root of', cube)
# Out:
# num_guesses = 14
# 3.000091552734375 is close to the cube root of 27
